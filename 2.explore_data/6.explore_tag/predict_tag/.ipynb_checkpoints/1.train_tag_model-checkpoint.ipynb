# %%
import xgboost as xgb
import sys,random
import pickle
import os
import numpy as np

# %%
# import modin.pandas as pd
import pandas as pd

# %%
if not os.path.exists('featurescore'):
    os.mkdir('featurescore')
if not os.path.exists('model'):
    os.mkdir('model')
if not os.path.exists('preds'):
    os.mkdir('preds')

# %%
# %%time
data_date = pd.read_csv('../../preprocess_data_new/train_ax_date.csv').drop(columns=['id'])
data_row_null = pd.read_csv('../../preprocess_data_new/train_ax_row_null.csv').drop(columns=['id'])
data_cat = pd.read_csv('../../preprocess_data_new/train_ax_cat.csv').drop(columns=['id']) 
data_cont = pd.read_csv('../../preprocess_data_new/train_ax_cont.csv') # 忘记导入id这一列
# Out:
# CPU times: user 2min 39s, sys: 12.1 s, total: 2min 51s
# Wall time: 3min 4s

# %%
# %%time
data = pd.concat([data_date,data_row_null,data_cat,data_cont],axis=1)
# Out:
# CPU times: user 17.7 s, sys: 804 ms, total: 18.5 s
# Wall time: 18.5 s

# %%
# %%time
data_tag = pd.read_csv('../../preprocess_data_new/train_ax1.csv',usecols=['tag'])
# Out:
# CPU times: user 25.9 s, sys: 1.06 s, total: 27 s
# Wall time: 41.7 s

# %% [markdown]
# ## 交叉验证

# %%
from sklearn.model_selection import train_test_split # 分割数据模块
from sklearn.metrics import roc_curve
from sklearn import metrics
#1.分割数据
X_train, X_test, y_train, y_test = train_test_split(data.values,data_tag.values,test_size=0.3, random_state=0)
#2.建立模型
params={
    'booster':'gbtree',
    'objective': 'binary:logistic',
    'early_stopping_rounds':100,
    'scale_pos_weight': float(len(data_tag)-np.sum(data_tag.values))/float(np.sum(data_tag.values)),  # 负例样本除以正例样本
    'eval_metric': 'auc',
    'gamma':1,
    'max_depth':6,
    'lambda':1,
    'subsample':0.9,
    'colsample_bytree':0.9,
    'min_child_weight':1, 
    'eta': 0.04,
    'seed':1080,
    'nthread':16
        }
#3.训练模型
dtrain = xgb.DMatrix(X_train, label=y_train)
watchlist  = [(dtrain,'train')]
print('开始训练！')
model  = xgb.train(params,dtrain,num_boost_round=800,evals=watchlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6977da0f1f5b> in <module>()
#      21         }
#      22 #3.训练模型
# ---> 23 watchlist  = [(dtrain,'train')]
#      24 dtrain = xgb.DMatrix(X_train, label=y_train)
#      25 print('开始训练！')
#
# NameError: name 'dtrain' is not defined

# %%
# 4.预测结果
print('开始预测！')
dtest = xgb.DMatrix(X_test)
y_pre = model.predict(dtest)
auc = metrics.roc_auc_score(y_test, y_pre)
print('AUC:',auc)
# Out:
# 开始预测！
# AUC: 0.934890475530805

# %%
import gc
del dtrain,dtest,model
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6969c04d87f3> in <module>()
#       1 import gc
# ----> 2 del dtest,model
#       3 gc.collect()
#
# NameError: name 'dtest' is not defined

# %% [markdown]
# ## 训练与预测

# %%
# %%time
valid_date = pd.read_csv('../../preprocess_data_new/valid_date.csv').drop(columns=['id'])
valid_row_null = pd.read_csv('../../preprocess_data_new/valid_row_null.csv').drop(columns=['id'])
valid_cat = pd.read_csv('../../preprocess_data_new/valid_cat.csv').drop(columns=['id']) 
valid_cont = pd.read_csv('../../preprocess_data_new/valid_cont.csv') # 忘记导入id这一列
# Out:
# CPU times: user 32 s, sys: 1.22 s, total: 33.3 s
# Wall time: 35.9 s

# %%
# %%time
valid = pd.concat([valid_date,valid_row_null,valid_cat,valid_cont],axis=1)
# Out:
# CPU times: user 2.31 s, sys: 64 ms, total: 2.37 s
# Wall time: 2.37 s

# %%
dtrain = xgb.DMatrix(data.values, data_tag.values, feature_names=list(data.columns))
dtest = xgb.DMatrix(valid.values, feature_names=list(valid.columns))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-33-12fce6af4f51> in <module>()
# ----> 1 dtrain = xgb.DMatrix(data.values, data_tag.values, feature_names=list(data.columns))
#       2 dtest = xgb.DMatrix(valid.values, feature_names=list(valid.columns))
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     278             self._init_from_csc(data)
#     279         elif isinstance(data, np.ndarray):
# --> 280             self._init_from_npy2d(data, missing, nthread)
#     281         else:
#     282             try:
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in _init_from_npy2d(self, mat, missing, nthread)
#     346         # we try to avoid data copies if possible (reshape returns a view when possible
#     347         # and we explicitly tell np.array to try and avoid copying)
# --> 348         data = np.array(mat.reshape(mat.size), copy=False, dtype=np.float32)
#     349         self.handle = ctypes.c_void_p()
#     350         missing = missing if missing is not None else np.nan
#
# MemoryError:

# %%
test_id = pd.read_csv('../../preprocess_data_new/valid_date.csv',usecols=['id']).values

# %%
def pipeline(dtrain,dtest,test_id,iteration,random_seed,gamma,max_depth,lambd,subsample,colsample_bytree,min_child_weight):
    if max_depth==6:
        num_boost_round = 800
    elif max_depth==7:
        num_boost_round = 650
    elif max_depth==8:
        num_boost_round = 500
    
    params={
    'booster':'gbtree',
    'objective': 'binary:logistic',
    'early_stopping_rounds':100,
    'scale_pos_weight': float(len(data_tag)-np.sum(data_tag.values))/float(np.sum(data_tag.values)),  # 负例样本除以正例样本
    'eval_metric': 'auc',
    'gamma':gamma,
    'max_depth':max_depth,
    'lambda':lambd,
    'subsample':subsample,
    'colsample_bytree':colsample_bytree,
    'min_child_weight':min_child_weight, 
    'eta': 0.04,
    'seed':random_seed,
    'nthread':16
        }
    watchlist  = [(dtrain,'train')]
    model = xgb.train(params,dtrain,num_boost_round=num_boost_round,evals=watchlist)
    model.save_model('./model/xgb{0}.model'.format(iteration))
    
    #predict test set
    test_y = model.predict(dtest)
    test_result = pd.DataFrame(test_id,columns=["id"])
    test_result['score'] = test_y
    test_result.to_csv("./preds/xgb{0}.csv".format(iteration),index=None,encoding='utf-8')
    
    #get feature score
    feature_score = model.get_fscore()
    feature_score = sorted(feature_score.items(), key=lambda x:x[1],reverse=True)
    fs = []
    for (key,value) in feature_score:
        fs.append("{0},{1}\n".format(key,value))
    
    with open('./featurescore/feature_score_{0}.csv'.format(iteration),'w') as f:
        f.writelines("feature,score\n")
        f.writelines(fs)

# %%
# %%time
random_seed = list(range(1000,2000,20))
gamma = [i/1000.0 for i in range(100,200,2)]
max_depth = [6,7,8]
lambd = list(range(200,400,2))
subsample = [i/1000.0 for i in range(600,700,2)]
colsample_bytree = [i/1000.0 for i in range(250,350,2)]
min_child_weight = [i/1000.0 for i in range(200,300,2)]
random.shuffle(random_seed)
random.shuffle(gamma)
random.shuffle(max_depth)
random.shuffle(lambd)
random.shuffle(subsample)
random.shuffle(colsample_bytree)
random.shuffle(min_child_weight)

with open('params.pkl','wb') as f:
    pickle.dump((random_seed,gamma,max_depth,lambd,subsample,colsample_bytree,min_child_weight),f)

#to reproduce my result, uncomment following lines
"""
with open('params_for_reproducing.pkl','rb') as f:
    random_seed,gamma,max_depth,lambd,subsample,colsample_bytree,min_child_weight = pickle.load(f)    
"""

for i in range(8):
    pipeline(dtrain,dtest,test_id,i,random_seed[i],gamma[i],max_depth[i%3],lambd[i],subsample[i],colsample_bytree[i],min_child_weight[i])
# Out:
# [0]	train-auc:0.783166
# [1]	train-auc:0.805088
# [2]	train-auc:0.819366
# [3]	train-auc:0.850116
# [4]	train-auc:0.849013
# [5]	train-auc:0.859144
# [6]	train-auc:0.863715
# [7]	train-auc:0.865602
# [8]	train-auc:0.868001
# [9]	train-auc:0.868062
# [10]	train-auc:0.869361
# [11]	train-auc:0.869488
# [12]	train-auc:0.870129
# [13]	train-auc:0.872849
# [14]	train-auc:0.873232
# [15]	train-auc:0.875303
# [16]	train-auc:0.876499
# [17]	train-auc:0.876202
# [18]	train-auc:0.876604
# [19]	train-auc:0.877061
# [20]	train-auc:0.880017
# [21]	train-auc:0.881517
# [22]	train-auc:0.881468
# [23]	train-auc:0.881777
# [24]	train-auc:0.882532
# [25]	train-auc:0.883824
# [26]	train-auc:0.884222
# [27]	train-auc:0.885277
# [28]	train-auc:0.886281
# [29]	train-auc:0.886213
# [30]	train-auc:0.887846
# [31]	train-auc:0.888362
# [32]	train-auc:0.888104
# [33]	train-auc:0.888949
# [34]	train-auc:0.889597
# [35]	train-auc:0.890893
# [36]	train-auc:0.891157
# [37]	train-auc:0.89157
# [38]	train-auc:0.8919
# [39]	train-auc:0.892508
# [40]	train-auc:0.892684
# [41]	train-auc:0.893191
# [42]	train-auc:0.893296
# [43]	train-auc:0.893911
# [44]	train-auc:0.894136
# [45]	train-auc:0.895171
# [46]	train-auc:0.895752
# [47]	train-auc:0.89692
# [48]	train-auc:0.89713
# [49]	train-auc:0.89733
# [50]	train-auc:0.897675
# [51]	train-auc:0.898003
# [52]	train-auc:0.898469
# [53]	train-auc:0.898617
# [54]	train-auc:0.899256
# [55]	train-auc:0.899334
# [56]	train-auc:0.900389
# [57]	train-auc:0.900643
# [58]	train-auc:0.901208
# [59]	train-auc:0.901252
# [60]	train-auc:0.901365
# [61]	train-auc:0.902246
# [62]	train-auc:0.902413
# [63]	train-auc:0.903024
# [64]	train-auc:0.903401
# [65]	train-auc:0.9036
# [66]	train-auc:0.904083
# [67]	train-auc:0.904836
# [567]	train-auc:0.956607
# [568]	train-auc:0.956652
# [569]	train-auc:0.956696
# [570]	train-auc:0.956735
# [571]	train-auc:0.956774
# [572]	train-auc:0.956789
# [573]	train-auc:0.95681
# [574]	train-auc:0.956856
# [575]	train-auc:0.956893
# [576]	train-auc:0.956925
# [577]	train-auc:0.956954
# [578]	train-auc:0.956989
# [579]	train-auc:0.957014
# [580]	train-auc:0.957052
# [581]	train-auc:0.957074
# [582]	train-auc:0.957112
# [583]	train-auc:0.957139
# [584]	train-auc:0.957159
# [585]	train-auc:0.957197
# [586]	train-auc:0.957227
# [587]	train-auc:0.957252
# [588]	train-auc:0.957288
# [589]	train-auc:0.957314
# [590]	train-auc:0.957363
# [591]	train-auc:0.957398
# [592]	train-auc:0.95744
# [593]	train-auc:0.957478
# [594]	train-auc:0.957527
# [595]	train-auc:0.957559
# [596]	train-auc:0.957587
# [597]	train-auc:0.957617
# [598]	train-auc:0.957661
# [599]	train-auc:0.957695
# [600]	train-auc:0.957729
# [601]	train-auc:0.957765
# [602]	train-auc:0.957798
# [603]	train-auc:0.95784
# [604]	train-auc:0.957865
# [605]	train-auc:0.957894
# [606]	train-auc:0.957942
# [607]	train-auc:0.957981
# [608]	train-auc:0.958029
# [609]	train-auc:0.958069
# [610]	train-auc:0.958103
# [611]	train-auc:0.958148
# [612]	train-auc:0.958179
# [613]	train-auc:0.958225
# [614]	train-auc:0.958261
# [615]	train-auc:0.958277
# [616]	train-auc:0.958314
# [617]	train-auc:0.958346
# [618]	train-auc:0.958392
# [619]	train-auc:0.95842
# [620]	train-auc:0.958452
# [621]	train-auc:0.958491
# [622]	train-auc:0.958525
# [623]	train-auc:0.958565
# [624]	train-auc:0.958593
# [625]	train-auc:0.958631
# [626]	train-auc:0.958659
# [627]	train-auc:0.958687
# [628]	train-auc:0.958721
# [629]	train-auc:0.958764
# [630]	train-auc:0.958786
# [631]	train-auc:0.958827
# [632]	train-auc:0.958857
# [633]	train-auc:0.958891
# [634]	train-auc:0.95892
# [635]	train-auc:0.958963
# [636]	train-auc:0.958988
# [637]	train-auc:0.959012
# [638]	train-auc:0.959032
# [639]	train-auc:0.959055
# [640]	train-auc:0.959091
# [641]	train-auc:0.959123
# [642]	train-auc:0.959167
# [643]	train-auc:0.959198
# [644]	train-auc:0.959227
# [645]	train-auc:0.959264
# [646]	train-auc:0.959298
# [647]	train-auc:0.959329
# [648]	train-auc:0.959346
# [649]	train-auc:0.959376
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-31-a058e8c59f92> in pipeline(dtrain, dtest, test_id, iteration, random_seed, gamma, max_depth, lambd, subsample, colsample_bytree, min_child_weight)
#      28
#      29     #predict test set
# ---> 30     test_y = model.predict(dtest)
#      31     test_result = pd.DataFrame(test_id,columns=["id"])
#      32     test_result['score'] = test_y
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs)
#    1042             option_mask |= 0x08
#    1043
# -> 1044         self._validate_features(data)
#    1045
#    1046         length = c_bst_ulong()
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in _validate_features(self, data)
#    1286
#    1287                 raise ValueError(msg.format(self.feature_names,
# -> 1288                                             data.feature_names))
#    1289
#    1290     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: 